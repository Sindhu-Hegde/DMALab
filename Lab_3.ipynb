# %% [markdown]
# # LAB 1 CODE

# %%
##Exploring Traveler data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline 

print("Reading data...")
train_file = "train_users_2.csv"
df_train = pd.read_csv(train_file, header = 0,index_col=None)

test_file = "test_users.csv"
df_test = pd.read_csv(test_file, header = 0,index_col=None)

# Combining into one dataset for cleaning
df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)
print("Reading data...completed")

# Fixing date formats in Pandas - to_datetime
## Change dates to specific format
print("Fixing timestamps...")
df_all['date_account_created'] = pd.to_datetime(df_all['date_account_created'], format='%Y-%m-%d')
df_all['timestamp_first_active'] = pd.to_datetime(df_all['timestamp_first_active'], format='%Y%m%d%H%M%S')
print("Fixing timestamps...completed")

## Removing date_first_booking column
df_all.drop('date_first_booking', axis = 1, inplace = True)
print("Droped date_first_booking column...")

## Remove outliers function - [1]
def remove_outliers(df, column, min_val, max_val):
    col_values = df[column].values
    df[column] = np.where(np.logical_or(col_values<=min_val, col_values>=max_val), np.NaN, col_values)
    return df

## Fixing age column - [2]
print("Fixing age column...")
df_all = remove_outliers(df = df_all, column = 'age', min_val = 15, max_val = 90)
df_all['age'].fillna(-1, inplace = True)
print("Fixing age column...completed")

# Other column missing value - Fill first_affiliate_tracked column
print("Filling first_affiliate_tracked column...")
df_all['first_affiliate_tracked'].fillna(-1, inplace=True)
print("Filling first_affiliate_tracked column...completed")

df_all.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Reading data...
# Reading data...completed
# Fixing timestamps...
# Fixing timestamps...completed
# Droped date_first_booking column...
# Fixing age column...
# Fixing age column...completed
# Filling first_affiliate_tracked column...
# Filling first_affiliate_tracked column...completed
# /home/ubnatu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in less_equal
# /home/ubnatu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in greater_equal
#   affiliate_channel affiliate_provider   age country_destination  \
# 0            direct             direct  -1.0                 NDF
# 1               seo             google  38.0                 NDF
# 2            direct             direct  56.0                  US
# 3            direct             direct  42.0               other
# 4            direct             direct  41.0                  US
#
#   date_account_created first_affiliate_tracked first_browser  \
# 0           2010-06-28               untracked        Chrome
# 1           2011-05-25               untracked        Chrome
# 2           2010-09-28               untracked            IE
# 3           2011-12-05               untracked       Firefox
# 4           2010-09-14               untracked        Chrome
#
#   first_device_type     gender          id language signup_app  signup_flow  \
# 0       Mac Desktop  -unknown-  gxn3p5htnn       en        Web            0
# 1       Mac Desktop       MALE  820tgsjxq7       en        Web            0
# 2   Windows Desktop     FEMALE  4ft3gnwmtx       en        Web            3
# 3       Mac Desktop     FEMALE  bjjt8pjhuk       en        Web            0
# 4       Mac Desktop  -unknown-  87mebub9p4       en        Web            0
#
#   signup_method timestamp_first_active
# 0      facebook    2009-03-19 04:32:55
# 1      facebook    2009-05-23 17:48:09
# 2         basic    2009-06-09 23:12:47
# 3      facebook    2009-10-31 06:01:29
# 4         basic    2009-12-08 06:11:05

# %% [markdown]
# # LAB 2 CODE

# %%
# Own implementation of One Hot Encoding - Data Transformation
def convert_to_binary(df, column_to_convert):
    categories = list(df[column_to_convert].drop_duplicates())

    for category in categories:
        cat_name = str(category).replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_").replace("-", "").lower()
        col_name = column_to_convert[:5] + '_' + cat_name[:10]
        df[col_name] = 0
        df.loc[(df[column_to_convert] == category), col_name] = 1

    return df

# One Hot Encoding
print("One Hot Encoding categorical data...")
columns_to_convert = ['gender', 'signup_method', 'signup_flow', 'language', 'affiliate_channel', 'affiliate_provider', 'first_affiliate_tracked', 'signup_app', 'first_device_type', 'first_browser']

for column in columns_to_convert:
    df_all = convert_to_binary(df=df_all, column_to_convert=column)
    df_all.drop(column, axis=1, inplace=True)
print("One Hot Encoding categorical data...completed")

# Add new date related fields - Creating New Features
print("Adding new fields...")
df_all['day_account_created'] = df_all['date_account_created'].dt.weekday
df_all['month_account_created'] = df_all['date_account_created'].dt.month
df_all['quarter_account_created'] = df_all['date_account_created'].dt.quarter
df_all['year_account_created'] = df_all['date_account_created'].dt.year
df_all['hour_first_active'] = df_all['timestamp_first_active'].dt.hour
df_all['day_first_active'] = df_all['timestamp_first_active'].dt.weekday
df_all['month_first_active'] = df_all['timestamp_first_active'].dt.month
df_all['quarter_first_active'] = df_all['timestamp_first_active'].dt.quarter
df_all['year_first_active'] = df_all['timestamp_first_active'].dt.year
df_all['created_less_active'] = (df_all['date_account_created'] - df_all['timestamp_first_active']).dt.days
print("Adding new fields...completed")


# Drop unnecessary columns
print("Droping fields...")
columns_to_drop = ['date_account_created', 'timestamp_first_active', 'date_first_booking', 'country_destination']
for column in columns_to_drop:
    if column in df_all.columns:
        df_all.drop(column, axis=1, inplace=True)
print("Droping fields...completed")

## Understanding the sessions.csv data
## Loading sessions.csv data
print("Reading sessions data...")
sessions_file = "sessions.csv"
df_sessions = pd.read_csv(sessions_file, header = 0,index_col=False)
print("Reading sessions data...completed")

## Cleaning and Transforming the Data
# Determine primary device
print("Determing primary device...")
sessions_device = df_sessions.loc[:, ['user_id', 'device_type', 'secs_elapsed']]
aggregated_lvl1 = sessions_device.groupby(['user_id', 'device_type'], as_index=False, sort=False).aggregate(np.sum)
#aggregated_lvl1.head(10)
idx = aggregated_lvl1.groupby(['user_id'], sort=False)['secs_elapsed'].transform(max) == aggregated_lvl1['secs_elapsed']
#idx.head(10)
df_sessions_primary = pd.DataFrame(aggregated_lvl1.loc[idx , ['user_id', 'device_type', 'secs_elapsed']])
#df_sessions_primary.head(10)
df_sessions_primary.rename(columns = {'device_type':'primary_device', 'secs_elapsed':'primary_secs'}, inplace=True)
#df_sessions_primary.head(10)
# Call user defined One Hot Encoding function
df_sessions_primary = convert_to_binary(df=df_sessions_primary, column_to_convert='primary_device')
#df_sessions_primary.head()
df_sessions_primary.drop('primary_device', axis=1, inplace=True)
#df_sessions_primary.head()
print("Determing primary device...completed")

# Determine Secondary device
print("Determing secondary device...")
remaining = aggregated_lvl1.drop(aggregated_lvl1.index[idx])
remaining.head()
idx = remaining.groupby(['user_id'], sort=False)['secs_elapsed'].transform(max) == remaining['secs_elapsed']
df_sessions_secondary = pd.DataFrame(remaining.loc[idx , ['user_id', 'device_type', 'secs_elapsed']])
df_sessions_secondary.rename(columns = {'device_type':'secondary_device', 'secs_elapsed':'secondary_secs'}, inplace=True)
df_sessions_secondary = convert_to_binary(df=df_sessions_secondary, column_to_convert='secondary_device')
df_sessions_secondary.drop('secondary_device', axis=1, inplace=True)
print("Determing secondary device...completed")

# Determine Counts of Actions - Looping Through the Actions Columns
# Count occurrences of value in a column
def convert_to_counts(df, id_col, column_to_convert):
    id_list = df[id_col].drop_duplicates()

    df_counts = df.loc[:,[id_col, column_to_convert]]
    df_counts['count'] = 1
    df_counts = df_counts.groupby(by=[id_col, column_to_convert], as_index=False, sort=False).sum()

    new_df = df_counts.pivot(index=id_col, columns=column_to_convert, values='count')
    new_df = new_df.fillna(0)

# Rename Columns
    categories = list(df[column_to_convert].drop_duplicates())
    for category in categories:
        cat_name = str(category).replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_").replace("-", "").lower()
        col_name = column_to_convert + '_' + cat_name
        new_df.rename(columns = {category:col_name}, inplace=True)

    return new_df

# Aggregate and combine actions taken columns
print("Aggregating actions taken...")
session_actions = df_sessions.loc[:,['user_id', 'action', 'action_type', 'action_detail']]
columns_to_convert = ['action', 'action_type', 'action_detail']
session_actions = session_actions.fillna('not provided')
first = True

for column in columns_to_convert:
    print("Converting " + column + " column...")
    current_data = convert_to_counts(df=session_actions, id_col='user_id', column_to_convert=column)

# If first loop, current data becomes existing data, otherwise merge existing and current
if first:
    first = False
    actions_data = current_data
else:
    actions_data = pd.concat([actions_data, current_data], axis=1, join='inner')

# Finally, Combine Data Sets
# [4.1] Merge device datasets - First, combine the two device dataframes (df_primary and df_secondary) to create a device dataframe.
print("Combining results...")
df_sessions_primary.set_index('user_id', inplace=True)
df_sessions_secondary.set_index('user_id', inplace=True)
device_data = pd.concat([df_sessions_primary, df_sessions_secondary], axis=1, join="outer")

# [4.2] Merge device and actions datasets - Then, combine the device dataframe with the actions dataframe to create a sessions dataframe with all the features extracted from sessions.csv
combined_results = pd.concat([device_data, actions_data], axis=1, join='outer')
df_sessions_complete = combined_results.fillna(0)

# [4.3] Merge user and session datasets - Finally, combine the sessions dataframe with the user data dataframe computed earlier
df_all.set_index('id', inplace=True)
df_all = pd.concat([df_all, df_sessions_complete], axis=1, join='inner')
print("Combining results...completed")

df_all.head() # You need get 5 rows × 349 columns
# Out:
# One Hot Encoding categorical data...
# One Hot Encoding categorical data...completed
# Adding new fields...
# Adding new fields...completed
# Droping fields...
# Droping fields...completed
# Reading sessions data...
# Reading sessions data...completed
# Determing primary device...
# Determing primary device...completed
# Determing secondary device...
# Determing secondary device...completed
# Aggregating actions taken...
# Converting action column...
# Converting action_type column...
# Converting action_detail column...
# Combining results...
# Combining results...completed
#              age  gende_unknown  gende_male  gende_female  gende_other  \
# d1mm9tcy42  62.0              0           1             0            0
# yo8nz8bqcq  -1.0              1           0             0            0
# 4grx6yxeby  -1.0              1           0             0            0
# ncf87guaf0  -1.0              1           0             0            0
# 4rvqpxoh3h  -1.0              1           0             0            0
#
#             signu_facebook  signu_basic  signu_google  signu_weibo  signu_0  \
# d1mm9tcy42               0            1             0            0        1
# yo8nz8bqcq               0            1             0            0        1
# 4grx6yxeby               0            1             0            0        1
# ncf87guaf0               0            1             0            0        1
# 4rvqpxoh3h               0            1             0            0        0
#
#                       ...             action_detail_view_resolutions  \
# d1mm9tcy42            ...                                        0.0
# yo8nz8bqcq            ...                                        0.0
# 4grx6yxeby            ...                                        0.0
# ncf87guaf0            ...                                        0.0
# 4rvqpxoh3h            ...                                        0.0
#
#             action_detail_view_search_results  \
# d1mm9tcy42                               23.0
# yo8nz8bqcq                                0.0
# 4grx6yxeby                                0.0
# ncf87guaf0                               32.0
# 4rvqpxoh3h                                0.0
#
#             action_detail_view_security_checks  \
# d1mm9tcy42                                 0.0
# yo8nz8bqcq                                 0.0
# 4grx6yxeby                                 0.0
# ncf87guaf0                                 0.0
# 4rvqpxoh3h                                 0.0
#
#             action_detail_view_user_real_names  action_detail_wishlist  \
# d1mm9tcy42                                 0.0                     0.0
# yo8nz8bqcq                                 0.0                     0.0
# 4grx6yxeby                                 0.0                     0.0
# ncf87guaf0                                 0.0                     0.0
# 4rvqpxoh3h                                 0.0                     0.0
#
#             action_detail_wishlist_content_update  \
# d1mm9tcy42                                   25.0
# yo8nz8bqcq                                    1.0
# 4grx6yxeby                                    1.0
# ncf87guaf0                                   10.0
# 4rvqpxoh3h                                    0.0
#
#             action_detail_wishlist_note  action_detail_your_listings  \
# d1mm9tcy42                          0.0                          0.0
# yo8nz8bqcq                          0.0                          0.0
# 4grx6yxeby                          0.0                          0.0
# ncf87guaf0                          0.0                          0.0
# 4rvqpxoh3h                          0.0                          0.0
#
#             action_detail_your_reservations  action_detail_your_trips
# d1mm9tcy42                              0.0                       0.0
# yo8nz8bqcq                              0.0                       0.0
# 4grx6yxeby                              0.0                       0.0
# ncf87guaf0                              0.0                       0.0
# 4rvqpxoh3h                              0.0                       0.0
#
# [5 rows x 349 columns]

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# Ensemble Methods:
# -Random Forest
# -Boosting
#
# # Cross Validation
#
# Split the data
# Training Data | Validation Data | Test Data
#
# k=3 CV (k=3 : 3 fold)
# TD1 | TD2 | VD  :  Acc 1
# VD | TD1 | TD2  :  Acc 2
# TD1 | VD | TD2  :  Acc 3
#
# Avg Acc = 70%
#
# Now bring the test data and check its accuracy

# %%
df_train1 = df_train
df_test1 = df_test
df_all1 = df_all
df_train1.set_index('id', inplace = True)
df_train1 = pd.concat([df_train1['country_destination'], df_all], axis=1, join='inner')

# %%
df_train1.shape
# Out:
# (73815, 350)

# %%
df_train1.head()
# Out:
#            country_destination   age  gende_unknown  gende_male  gende_female  \
# d1mm9tcy42               other  62.0              0           1             0
# yo8nz8bqcq                 NDF  -1.0              1           0             0
# 4grx6yxeby                 NDF  -1.0              1           0             0
# ncf87guaf0                 NDF  -1.0              1           0             0
# 4rvqpxoh3h                  GB  -1.0              1           0             0
#
#             gende_other  signu_facebook  signu_basic  signu_google  \
# d1mm9tcy42            0               0            1             0
# yo8nz8bqcq            0               0            1             0
# 4grx6yxeby            0               0            1             0
# ncf87guaf0            0               0            1             0
# 4rvqpxoh3h            0               0            1             0
#
#             signu_weibo            ...             \
# d1mm9tcy42            0            ...
# yo8nz8bqcq            0            ...
# 4grx6yxeby            0            ...
# ncf87guaf0            0            ...
# 4rvqpxoh3h            0            ...
#
#             action_detail_view_resolutions  action_detail_view_search_results  \
# d1mm9tcy42                             0.0                               23.0
# yo8nz8bqcq                             0.0                                0.0
# 4grx6yxeby                             0.0                                0.0
# ncf87guaf0                             0.0                               32.0
# 4rvqpxoh3h                             0.0                                0.0
#
#             action_detail_view_security_checks  \
# d1mm9tcy42                                 0.0
# yo8nz8bqcq                                 0.0
# 4grx6yxeby                                 0.0
# ncf87guaf0                                 0.0
# 4rvqpxoh3h                                 0.0
#
#             action_detail_view_user_real_names  action_detail_wishlist  \
# d1mm9tcy42                                 0.0                     0.0
# yo8nz8bqcq                                 0.0                     0.0
# 4grx6yxeby                                 0.0                     0.0
# ncf87guaf0                                 0.0                     0.0
# 4rvqpxoh3h                                 0.0                     0.0
#
#             action_detail_wishlist_content_update  \
# d1mm9tcy42                                   25.0
# yo8nz8bqcq                                    1.0
# 4grx6yxeby                                    1.0
# ncf87guaf0                                   10.0
# 4rvqpxoh3h                                    0.0
#
#             action_detail_wishlist_note  action_detail_your_listings  \
# d1mm9tcy42                          0.0                          0.0
# yo8nz8bqcq                          0.0                          0.0
# 4grx6yxeby                          0.0                          0.0
# ncf87guaf0                          0.0                          0.0
# 4rvqpxoh3h                          0.0                          0.0
#
#             action_detail_your_reservations  action_detail_your_trips
# d1mm9tcy42                              0.0                       0.0
# yo8nz8bqcq                              0.0                       0.0
# 4grx6yxeby                              0.0                       0.0
# ncf87guaf0                              0.0                       0.0
# 4rvqpxoh3h                              0.0                       0.0
#
# [5 rows x 350 columns]

# %%
from sklearn.preprocessing import LabelEncoder

id_train = df_train1.index.values
labels = df_train1['country_destination']

le = LabelEncoder()
y = le.fit_transform(labels)
x = df_train1.drop('country_destination', axis = 1, inplace = False)

# %%
df_train1.head()
# Out:
#            country_destination   age  gende_unknown  gende_male  gende_female  \
# d1mm9tcy42               other  62.0              0           1             0
# yo8nz8bqcq                 NDF  -1.0              1           0             0
# 4grx6yxeby                 NDF  -1.0              1           0             0
# ncf87guaf0                 NDF  -1.0              1           0             0
# 4rvqpxoh3h                  GB  -1.0              1           0             0
#
#             gende_other  signu_facebook  signu_basic  signu_google  \
# d1mm9tcy42            0               0            1             0
# yo8nz8bqcq            0               0            1             0
# 4grx6yxeby            0               0            1             0
# ncf87guaf0            0               0            1             0
# 4rvqpxoh3h            0               0            1             0
#
#             signu_weibo            ...             \
# d1mm9tcy42            0            ...
# yo8nz8bqcq            0            ...
# 4grx6yxeby            0            ...
# ncf87guaf0            0            ...
# 4rvqpxoh3h            0            ...
#
#             action_detail_view_resolutions  action_detail_view_search_results  \
# d1mm9tcy42                             0.0                               23.0
# yo8nz8bqcq                             0.0                                0.0
# 4grx6yxeby                             0.0                                0.0
# ncf87guaf0                             0.0                               32.0
# 4rvqpxoh3h                             0.0                                0.0
#
#             action_detail_view_security_checks  \
# d1mm9tcy42                                 0.0
# yo8nz8bqcq                                 0.0
# 4grx6yxeby                                 0.0
# ncf87guaf0                                 0.0
# 4rvqpxoh3h                                 0.0
#
#             action_detail_view_user_real_names  action_detail_wishlist  \
# d1mm9tcy42                                 0.0                     0.0
# yo8nz8bqcq                                 0.0                     0.0
# 4grx6yxeby                                 0.0                     0.0
# ncf87guaf0                                 0.0                     0.0
# 4rvqpxoh3h                                 0.0                     0.0
#
#             action_detail_wishlist_content_update  \
# d1mm9tcy42                                   25.0
# yo8nz8bqcq                                    1.0
# 4grx6yxeby                                    1.0
# ncf87guaf0                                   10.0
# 4rvqpxoh3h                                    0.0
#
#             action_detail_wishlist_note  action_detail_your_listings  \
# d1mm9tcy42                          0.0                          0.0
# yo8nz8bqcq                          0.0                          0.0
# 4grx6yxeby                          0.0                          0.0
# ncf87guaf0                          0.0                          0.0
# 4rvqpxoh3h                          0.0                          0.0
#
#             action_detail_your_reservations  action_detail_your_trips
# d1mm9tcy42                              0.0                       0.0
# yo8nz8bqcq                              0.0                       0.0
# 4grx6yxeby                              0.0                       0.0
# ncf87guaf0                              0.0                       0.0
# 4rvqpxoh3h                              0.0                       0.0
#
# [5 rows x 350 columns]

# %%
x.shape
# Out:
# (73815, 349)

# %%
x.head()
# Out:
#              age  gende_unknown  gende_male  gende_female  gende_other  \
# d1mm9tcy42  62.0              0           1             0            0
# yo8nz8bqcq  -1.0              1           0             0            0
# 4grx6yxeby  -1.0              1           0             0            0
# ncf87guaf0  -1.0              1           0             0            0
# 4rvqpxoh3h  -1.0              1           0             0            0
#
#             signu_facebook  signu_basic  signu_google  signu_weibo  signu_0  \
# d1mm9tcy42               0            1             0            0        1
# yo8nz8bqcq               0            1             0            0        1
# 4grx6yxeby               0            1             0            0        1
# ncf87guaf0               0            1             0            0        1
# 4rvqpxoh3h               0            1             0            0        0
#
#                       ...             action_detail_view_resolutions  \
# d1mm9tcy42            ...                                        0.0
# yo8nz8bqcq            ...                                        0.0
# 4grx6yxeby            ...                                        0.0
# ncf87guaf0            ...                                        0.0
# 4rvqpxoh3h            ...                                        0.0
#
#             action_detail_view_search_results  \
# d1mm9tcy42                               23.0
# yo8nz8bqcq                                0.0
# 4grx6yxeby                                0.0
# ncf87guaf0                               32.0
# 4rvqpxoh3h                                0.0
#
#             action_detail_view_security_checks  \
# d1mm9tcy42                                 0.0
# yo8nz8bqcq                                 0.0
# 4grx6yxeby                                 0.0
# ncf87guaf0                                 0.0
# 4rvqpxoh3h                                 0.0
#
#             action_detail_view_user_real_names  action_detail_wishlist  \
# d1mm9tcy42                                 0.0                     0.0
# yo8nz8bqcq                                 0.0                     0.0
# 4grx6yxeby                                 0.0                     0.0
# ncf87guaf0                                 0.0                     0.0
# 4rvqpxoh3h                                 0.0                     0.0
#
#             action_detail_wishlist_content_update  \
# d1mm9tcy42                                   25.0
# yo8nz8bqcq                                    1.0
# 4grx6yxeby                                    1.0
# ncf87guaf0                                   10.0
# 4rvqpxoh3h                                    0.0
#
#             action_detail_wishlist_note  action_detail_your_listings  \
# d1mm9tcy42                          0.0                          0.0
# yo8nz8bqcq                          0.0                          0.0
# 4grx6yxeby                          0.0                          0.0
# ncf87guaf0                          0.0                          0.0
# 4rvqpxoh3h                          0.0                          0.0
#
#             action_detail_your_reservations  action_detail_your_trips
# d1mm9tcy42                              0.0                       0.0
# yo8nz8bqcq                              0.0                       0.0
# 4grx6yxeby                              0.0                       0.0
# ncf87guaf0                              0.0                       0.0
# 4rvqpxoh3h                              0.0                       0.0
#
# [5 rows x 349 columns]

# %%
y.shape
# Out:
# (73815,)

# %%
labels
# Out:
# d1mm9tcy42    other
# yo8nz8bqcq      NDF
# 4grx6yxeby      NDF
# ncf87guaf0      NDF
# 4rvqpxoh3h       GB
# c8mfesvkv0      NDF
# xwxei6hdk4       US
# 5f45ro5uzk      NDF
# ro2stddszp    other
# qtw88d9pbl      NDF
# awiurksqr3       US
# ucgks2fyez    other
# j30uqo74v6      NDF
# cuxu2kbaep      NDF
# jrqykh9y8x       FR
# s9xrwtyzsq       US
# 1ltangt0hg      NDF
# j0mufvhhoh      NDF
# mde5wnphhf      NDF
# 11581i5wng       FR
# 8s14bomsx5      NDF
# ayguekg4tf      NDF
# vyv9bj70kd      NDF
# zc77z91crs      NDF
# 7s5yhmyxmj      NDF
# toga865pvz      NDF
# oa8oz6sj6s       US
# i7svun9mus      NDF
# w19d8pogt0      NDF
# 7105aijtcm      NDF
#               ...
# c98s3h7kgj      NDF
# ytmpiwb8hj      NDF
# 3dx1jk6yk2      NDF
# hcfj07iowv      NDF
# l1f71f9vsj      NDF
# 15bj4ahmhf      NDF
# qwpybxfjdl      NDF
# k4t61wuvyq      NDF
# mhh7b52z44      NDF
# 79wk7k2k5t      NDF
# ftwmocvwlq      NDF
# rg7ayg1tob      NDF
# 2f24umzkuv      NDF
# or77n2ojuj      NDF
# 0a5bnb9bs4      NDF
# 6fzrn49sfn      NDF
# r0jq0devgy      NDF
# v5lq9bj8gv      NDF
# msucfwmlzc       US
# 04y8115avm      NDF
# omlc9iku7t       ES
# rf0ay567js      NDF
# 0k26r3mir0       US
# 40o1ivh6cb      NDF
# qbxza0xojf       US
# zxodksqpep      NDF
# mhewnxesx9      NDF
# 6o3arsjbb4      NDF
# jh95kwisub      NDF
# nw9fwlyb5f      NDF
# Name: country_destination, Length: 73815, dtype: object

# %%
y
# Out:
# array([11,  7,  7, ...,  7,  7,  7])

# %%
from sklearn import cross_validation
features_train, features_test, labels_train, labels_test = cross_validation.train_test_split(x, y, test_size=0.3, random_state = 42)
# Out:
# /home/ubnatu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
features_train
# Out:
#              age  gende_unknown  gende_male  gende_female  gende_other  \
# yq9l4gresp  -1.0              1           0             0            0
# rkysvxwgif  -1.0              1           0             0            0
# 4okzo0h31v  -1.0              1           0             0            0
# waj2fu7aqw  -1.0              1           0             0            0
# pc3f35de0s  -1.0              1           0             0            0
# 783nyam7lf  -1.0              1           0             0            0
# 5lolu8ir9b  31.0              0           1             0            0
# nl1xby3e4e  29.0              0           0             1            0
# e21s43n1yn  28.0              0           1             0            0
# csexvvmfgk  -1.0              1           0             0            0
# h3o5l1qzmg  25.0              1           0             0            0
# qbtqlldd1w  -1.0              1           0             0            0
# i903ill900  21.0              1           0             0            0
# 0y381k04if  31.0              0           0             1            0
# 9ix98y3bun  29.0              0           1             0            0
# qvl0x4w142  -1.0              1           0             0            0
# de921vj0ba  -1.0              1           0             0            0
# sj8so99onw  54.0              0           0             1            0
# wq3m98fl7d  32.0              0           1             0            0
# jym9msc1du  25.0              0           0             1            0
# 9liag7c30i  -1.0              1           0             0            0
# 7l4otb8cr2  49.0              0           0             1            0
# nvx9geb66e  -1.0              1           0             0            0
# my51va0pls  -1.0              0           1             0            0
# e9wnmbr4ti  -1.0              1           0             0            0
# pqq2szeh2g  -1.0              1           0             0            0
# pqadfv49vt  32.0              0           0             1            0
# ybgil155f4  58.0              0           0             1            0
# o58yzlh58f  23.0              0           0             1            0
# waasc88ia3  30.0              0           0             1            0
# ...          ...            ...         ...           ...          ...
# k1m023wfmg  48.0              0           1             0            0
# g1ekfb3bu8  53.0              0           0             1            0
# vy3vwm9oja  26.0              0           0             1            0
# 7iwh7vh19t  35.0              1           0             0            0
# yh74l49bl1  -1.0              1           0             0            0
# ydzqhu05rx  -1.0              1           0             0            0
# xkivadk1af  -1.0              1           0             0            0
# 3cnu02brvq  28.0              0           0             1            0
# nbmnlo5q73  -1.0              1           0             0            0
# wg6gcq5hlj  29.0              0           1             0            0
# sxu3clenta  33.0              0           1             0            0
# xjmld7nqck  55.0              0           0             1            0
# v2elwr037d  36.0              0           0             1            0
# 1n2429cp96  26.0              0           1             0            0
# 620o2hyynw  26.0              0           1             0            0
# hc7bboi9gr  -1.0              1           0             0            0
# r8ajngns16  24.0              0           1             0            0
# fn6zvy0sm4  26.0              0           1             0            0
# dq48lzniy1  38.0              1           0             0            0
# lo1wc1t110  -1.0              1           0             0            0
# s2dhyi4hst  20.0              0           0             1            0
# jjbqps9hvb  30.0              0           0             1            0
# 7quv1cccrv  30.0              0           1             0            0
# ck8c7dyd1i  31.0              0           1             0            0
# yorn50cin7  42.0              0           1             0            0
# wostlok7dp  60.0              0           0             1            0
# fs115l1v0k  -1.0              1           0             0            0
# mo7yckrlc5  47.0              0           1             0            0
# 6p5y5o0jbx  -1.0              1           0             0            0
# acxy7vq566  -1.0              1           0             0            0
#
#             signu_facebook  signu_basic  signu_google  signu_weibo  signu_0  \
# yq9l4gresp               0            1             0            0        0
# rkysvxwgif               0            1             0            0        0
# 4okzo0h31v               0            1             0            0        1
# waj2fu7aqw               0            1             0            0        1
# pc3f35de0s               0            1             0            0        1
# 783nyam7lf               0            1             0            0        1
# 5lolu8ir9b               0            1             0            0        0
# nl1xby3e4e               1            0             0            0        1
# e21s43n1yn               0            1             0            0        1
# csexvvmfgk               0            1             0            0        1
# h3o5l1qzmg               0            1             0            0        1
# qbtqlldd1w               0            0             1            0        0
# i903ill900               0            1             0            0        1
# 0y381k04if               1            0             0            0        0
# 9ix98y3bun               1            0             0            0        0
# qvl0x4w142               0            1             0            0        1
# de921vj0ba               0            1             0            0        1
# sj8so99onw               0            1             0            0        1
# wq3m98fl7d               1            0             0            0        1
# jym9msc1du               1            0             0            0        1
# 9liag7c30i               0            1             0            0        0
# 7l4otb8cr2               0            1             0            0        1
# nvx9geb66e               0            1             0            0        1
# my51va0pls               0            1             0            0        0
# e9wnmbr4ti               0            1             0            0        1
# pqq2szeh2g               0            1             0            0        1
# pqadfv49vt               0            1             0            0        1
# ybgil155f4               1            0             0            0        1
# o58yzlh58f               0            1             0            0        1
# waasc88ia3               1            0             0            0        1
# ...                    ...          ...           ...          ...      ...
# k1m023wfmg               1            0             0            0        1
# g1ekfb3bu8               0            1             0            0        1
# vy3vwm9oja               1            0             0            0        1
# 7iwh7vh19t               0            1             0            0        1
# yh74l49bl1               0            1             0            0        1
# ydzqhu05rx               0            1             0            0        1
# xkivadk1af               0            1             0            0        1
# 3cnu02brvq               0            1             0            0        1
# nbmnlo5q73               0            1             0            0        1
# wg6gcq5hlj               1            0             0            0        1
# sxu3clenta               0            1             0            0        1
# xjmld7nqck               0            1             0            0        1
# v2elwr037d               0            1             0            0        1
# 1n2429cp96               1            0             0            0        0
# 620o2hyynw               0            1             0            0        1
# hc7bboi9gr               0            1             0            0        0
# r8ajngns16               1            0             0            0        1
# fn6zvy0sm4               1            0             0            0        1
# dq48lzniy1               0            1             0            0        1
# lo1wc1t110               0            1             0            0        0
# s2dhyi4hst               0            1             0            0        1
# jjbqps9hvb               0            1             0            0        1
# 7quv1cccrv               0            1             0            0        1
# ck8c7dyd1i               1            0             0            0        1
# yorn50cin7               0            1             0            0        1
# wostlok7dp               1            0             0            0        1
# fs115l1v0k               0            1             0            0        0
# mo7yckrlc5               1            0             0            0        1
# 6p5y5o0jbx               0            1             0            0        1
# acxy7vq566               0            1             0            0        1
#
#                       ...             action_detail_view_resolutions  \
# yq9l4gresp            ...                                        0.0
# rkysvxwgif            ...                                        0.0
# 4okzo0h31v            ...                                        0.0
# waj2fu7aqw            ...                                        0.0
# pc3f35de0s            ...                                        0.0
# 783nyam7lf            ...                                        0.0
# 5lolu8ir9b            ...                                        0.0
# nl1xby3e4e            ...                                        0.0
# e21s43n1yn            ...                                        0.0
# csexvvmfgk            ...                                        0.0
# h3o5l1qzmg            ...                                        0.0
# qbtqlldd1w            ...                                        0.0
# i903ill900            ...                                        0.0
# 0y381k04if            ...                                        0.0
# 9ix98y3bun            ...                                        0.0
# qvl0x4w142            ...                                        0.0
# de921vj0ba            ...                                        0.0
# sj8so99onw            ...                                        0.0
# wq3m98fl7d            ...                                        0.0
# jym9msc1du            ...                                        0.0
# 9liag7c30i            ...                                        0.0
# 7l4otb8cr2            ...                                        0.0
# nvx9geb66e            ...                                        0.0
# my51va0pls            ...                                        0.0
# e9wnmbr4ti            ...                                        0.0
# pqq2szeh2g            ...                                        0.0
# pqadfv49vt            ...                                        0.0
# ybgil155f4            ...                                        0.0
# o58yzlh58f            ...                                        0.0
# waasc88ia3            ...                                        0.0
# ...                   ...                                        ...
# k1m023wfmg            ...                                        0.0
# g1ekfb3bu8            ...                                        0.0
# vy3vwm9oja            ...                                        0.0
# 7iwh7vh19t            ...                                        0.0
# yh74l49bl1            ...                                        0.0
# ydzqhu05rx            ...                                        0.0
# xkivadk1af            ...                                        0.0
# 3cnu02brvq            ...                                        0.0
# nbmnlo5q73            ...                                        0.0
# wg6gcq5hlj            ...                                        0.0
# sxu3clenta            ...                                        0.0
# xjmld7nqck            ...                                        0.0
# v2elwr037d            ...                                        0.0
# 1n2429cp96            ...                                        0.0
# 620o2hyynw            ...                                        0.0
# hc7bboi9gr            ...                                        0.0
# r8ajngns16            ...                                        0.0
# fn6zvy0sm4            ...                                        0.0
# dq48lzniy1            ...                                        0.0
# lo1wc1t110            ...                                        0.0
# s2dhyi4hst            ...                                        0.0
# jjbqps9hvb            ...                                        0.0
# 7quv1cccrv            ...                                        0.0
# ck8c7dyd1i            ...                                        0.0
# yorn50cin7            ...                                        0.0
# wostlok7dp            ...                                        0.0
# fs115l1v0k            ...                                        0.0
# mo7yckrlc5            ...                                        0.0
# 6p5y5o0jbx            ...                                        0.0
# acxy7vq566            ...                                        0.0
#
#             action_detail_view_search_results  \
# yq9l4gresp                                0.0
# rkysvxwgif                                7.0
# 4okzo0h31v                                3.0
# waj2fu7aqw                                4.0
# pc3f35de0s                               11.0
# 783nyam7lf                                1.0
# 5lolu8ir9b                              503.0
# nl1xby3e4e                               80.0
# e21s43n1yn                               14.0
# csexvvmfgk                                1.0
# h3o5l1qzmg                                3.0
# qbtqlldd1w                                5.0
# i903ill900                                0.0
# 0y381k04if                                0.0
# 9ix98y3bun                               48.0
# qvl0x4w142                                0.0
# de921vj0ba                                0.0
# sj8so99onw                               11.0
# wq3m98fl7d                               10.0
# jym9msc1du                                0.0
# 9liag7c30i                                7.0
# 7l4otb8cr2                               28.0
# nvx9geb66e                               78.0
# my51va0pls                                0.0
# e9wnmbr4ti                                0.0
# pqq2szeh2g                               21.0
# pqadfv49vt                               11.0
# ybgil155f4                                0.0
# o58yzlh58f                                0.0
# waasc88ia3                                0.0
# ...                                       ...
# k1m023wfmg                                0.0
# g1ekfb3bu8                               12.0
# vy3vwm9oja                               27.0
# 7iwh7vh19t                                0.0
# yh74l49bl1                               53.0
# ydzqhu05rx                               18.0
# xkivadk1af                               16.0
# 3cnu02brvq                                6.0
# nbmnlo5q73                               14.0
# wg6gcq5hlj                               12.0
# sxu3clenta                                6.0
# xjmld7nqck                                2.0
# v2elwr037d                               35.0
# 1n2429cp96                                0.0
# 620o2hyynw                               48.0
# hc7bboi9gr                               14.0
# r8ajngns16                                0.0
# fn6zvy0sm4                                0.0
# dq48lzniy1                               55.0
# lo1wc1t110                                6.0
# s2dhyi4hst                                0.0
# jjbqps9hvb                                0.0
# 7quv1cccrv                                4.0
# ck8c7dyd1i                                0.0
# yorn50cin7                                1.0
# wostlok7dp                                0.0
# fs115l1v0k                                0.0
# mo7yckrlc5                                6.0
# 6p5y5o0jbx                                7.0
# acxy7vq566                               32.0
#
#             action_detail_view_security_checks  \
# yq9l4gresp                                 0.0
# rkysvxwgif                                 0.0
# 4okzo0h31v                                 0.0
# waj2fu7aqw                                 0.0
# pc3f35de0s                                 0.0
# 783nyam7lf                                 0.0
# 5lolu8ir9b                                 0.0
# nl1xby3e4e                                 0.0
# e21s43n1yn                                 0.0
# csexvvmfgk                                 0.0
# h3o5l1qzmg                                 0.0
# qbtqlldd1w                                 0.0
# i903ill900                                 0.0
# 0y381k04if                                 0.0
# 9ix98y3bun                                 0.0
# qvl0x4w142                                 0.0
# de921vj0ba                                 0.0
# sj8so99onw                                 0.0
# wq3m98fl7d                                 0.0
# jym9msc1du                                 0.0
# 9liag7c30i                                 0.0
# 7l4otb8cr2                                 0.0
# nvx9geb66e                                 0.0
# my51va0pls                                 0.0
# e9wnmbr4ti                                 0.0
# pqq2szeh2g                                 0.0
# pqadfv49vt                                 0.0
# ybgil155f4                                 0.0
# o58yzlh58f                                 0.0
# waasc88ia3                                 0.0
# ...                                        ...
# k1m023wfmg                                 0.0
# g1ekfb3bu8                                 0.0
# vy3vwm9oja                                 0.0
# 7iwh7vh19t                                 0.0
# yh74l49bl1                                 0.0
# ydzqhu05rx                                 0.0
# xkivadk1af                                 0.0
# 3cnu02brvq                                 0.0
# nbmnlo5q73                                 0.0
# wg6gcq5hlj                                 0.0
# sxu3clenta                                 0.0
# xjmld7nqck                                 0.0
# v2elwr037d                                 0.0
# 1n2429cp96                                 0.0
# 620o2hyynw                                 0.0
# hc7bboi9gr                                 0.0
# r8ajngns16                                 0.0
# fn6zvy0sm4                                 0.0
# dq48lzniy1                                 0.0
# lo1wc1t110                                 0.0
# s2dhyi4hst                                 0.0
# jjbqps9hvb                                 0.0
# 7quv1cccrv                                 0.0
# ck8c7dyd1i                                 0.0
# yorn50cin7                                 0.0
# wostlok7dp                                 0.0
# fs115l1v0k                                 0.0
# mo7yckrlc5                                 0.0
# 6p5y5o0jbx                                 0.0
# acxy7vq566                                 0.0
#
#             action_detail_view_user_real_names  action_detail_wishlist  \
# yq9l4gresp                                 0.0                     0.0
# rkysvxwgif                                 0.0                     0.0
# 4okzo0h31v                                 0.0                     0.0
# waj2fu7aqw                                 0.0                     0.0
# pc3f35de0s                                 0.0                     0.0
# 783nyam7lf                                 0.0                     0.0
# 5lolu8ir9b                                 0.0                     0.0
# nl1xby3e4e                                 0.0                     0.0
# e21s43n1yn                                 0.0                     0.0
# csexvvmfgk                                 0.0                     0.0
# h3o5l1qzmg                                 0.0                     0.0
# qbtqlldd1w                                 0.0                     0.0
# i903ill900                                 0.0                     0.0
# 0y381k04if                                 0.0                     0.0
# 9ix98y3bun                                 0.0                     0.0
# qvl0x4w142                                 0.0                     0.0
# de921vj0ba                                 0.0                     0.0
# sj8so99onw                                 0.0                     2.0
# wq3m98fl7d                                 0.0                     0.0
# jym9msc1du                                 0.0                     0.0
# 9liag7c30i                                 0.0                     0.0
# 7l4otb8cr2                                 0.0                     0.0
# nvx9geb66e                                 0.0                     0.0
# my51va0pls                                 0.0                     0.0
# e9wnmbr4ti                                 0.0                     0.0
# pqq2szeh2g                                 0.0                     0.0
# pqadfv49vt                                 0.0                     0.0
# ybgil155f4                                 0.0                     0.0
# o58yzlh58f                                 0.0                     0.0
# waasc88ia3                                 0.0                     0.0
# ...                                        ...                     ...
# k1m023wfmg                                 0.0                     0.0
# g1ekfb3bu8                                 0.0                     0.0
# vy3vwm9oja                                 0.0                     0.0
# 7iwh7vh19t                                 0.0                     0.0
# yh74l49bl1                                 0.0                     0.0
# ydzqhu05rx                                 0.0                     0.0
# xkivadk1af                                 0.0                     0.0
# 3cnu02brvq                                 0.0                     0.0
# nbmnlo5q73                                 0.0                     0.0
# wg6gcq5hlj                                 0.0                     0.0
# sxu3clenta                                 0.0                     0.0
# xjmld7nqck                                 0.0                     0.0
# v2elwr037d                                 0.0                     0.0
# 1n2429cp96                                 0.0                     0.0
# 620o2hyynw                                 0.0                    12.0
# hc7bboi9gr                                 0.0                     0.0
# r8ajngns16                                 0.0                     0.0
# fn6zvy0sm4                                 0.0                     0.0
# dq48lzniy1                                 0.0                     0.0
# lo1wc1t110                                 0.0                     0.0
# s2dhyi4hst                                 0.0                     0.0
# jjbqps9hvb                                 0.0                     0.0
# 7quv1cccrv                                 0.0                     0.0
# ck8c7dyd1i                                 0.0                     0.0
# yorn50cin7                                 0.0                     0.0
# wostlok7dp                                 0.0                     0.0
# fs115l1v0k                                 0.0                     0.0
# mo7yckrlc5                                 0.0                     0.0
# 6p5y5o0jbx                                 0.0                     0.0
# acxy7vq566                                 0.0                     0.0
#
#             action_detail_wishlist_content_update  \
# yq9l4gresp                                    0.0
# rkysvxwgif                                    5.0
# 4okzo0h31v                                    7.0
# waj2fu7aqw                                    4.0
# pc3f35de0s                                    7.0
# 783nyam7lf                                    1.0
# 5lolu8ir9b                                    0.0
# nl1xby3e4e                                   32.0
# e21s43n1yn                                    6.0
# csexvvmfgk                                    1.0
# h3o5l1qzmg                                    1.0
# qbtqlldd1w                                    0.0
# i903ill900                                    0.0
# 0y381k04if                                    0.0
# 9ix98y3bun                                    0.0
# qvl0x4w142                                    2.0
# de921vj0ba                                    0.0
# sj8so99onw                                    1.0
# wq3m98fl7d                                    4.0
# jym9msc1du                                    2.0
# 9liag7c30i                                    0.0
# 7l4otb8cr2                                   38.0
# nvx9geb66e                                   23.0
# my51va0pls                                    0.0
# e9wnmbr4ti                                    0.0
# pqq2szeh2g                                   19.0
# pqadfv49vt                                    3.0
# ybgil155f4                                    0.0
# o58yzlh58f                                    6.0
# waasc88ia3                                    0.0
# ...                                           ...
# k1m023wfmg                                    0.0
# g1ekfb3bu8                                    9.0
# vy3vwm9oja                                    6.0
# 7iwh7vh19t                                    0.0
# yh74l49bl1                                   16.0
# ydzqhu05rx                                   11.0
# xkivadk1af                                    8.0
# 3cnu02brvq                                    1.0
# nbmnlo5q73                                    6.0
# wg6gcq5hlj                                   48.0
# sxu3clenta                                    1.0
# xjmld7nqck                                    5.0
# v2elwr037d                                    8.0
# 1n2429cp96                                    0.0
# 620o2hyynw                                   63.0
# hc7bboi9gr                                    0.0
# r8ajngns16                                    0.0
# fn6zvy0sm4                                    0.0
# dq48lzniy1                                   52.0
# lo1wc1t110                                    0.0
# s2dhyi4hst                                    0.0
# jjbqps9hvb                                    0.0
# 7quv1cccrv                                    4.0
# ck8c7dyd1i                                    0.0
# yorn50cin7                                    0.0
# wostlok7dp                                    0.0
# fs115l1v0k                                    0.0
# mo7yckrlc5                                   26.0
# 6p5y5o0jbx                                   15.0
# acxy7vq566                                    9.0
#
#             action_detail_wishlist_note  action_detail_your_listings  \
# yq9l4gresp                          0.0                          0.0
# rkysvxwgif                          0.0                          0.0
# 4okzo0h31v                          0.0                          0.0
# waj2fu7aqw                          0.0                          0.0
# pc3f35de0s                          0.0                          0.0
# 783nyam7lf                          0.0                          0.0
# 5lolu8ir9b                          0.0                          0.0
# nl1xby3e4e                          0.0                          0.0
# e21s43n1yn                          0.0                          0.0
# csexvvmfgk                          0.0                          0.0
# h3o5l1qzmg                          0.0                          0.0
# qbtqlldd1w                          0.0                          0.0
# i903ill900                          0.0                          0.0
# 0y381k04if                          0.0                          0.0
# 9ix98y3bun                          0.0                          0.0
# qvl0x4w142                          0.0                          0.0
# de921vj0ba                          0.0                          0.0
# sj8so99onw                          0.0                          0.0
# wq3m98fl7d                          0.0                          0.0
# jym9msc1du                          0.0                          0.0
# 9liag7c30i                          0.0                          0.0
# 7l4otb8cr2                          0.0                          0.0
# nvx9geb66e                          0.0                          0.0
# my51va0pls                          0.0                          0.0
# e9wnmbr4ti                          0.0                          0.0
# pqq2szeh2g                          0.0                          0.0
# pqadfv49vt                          0.0                          0.0
# ybgil155f4                          0.0                          0.0
# o58yzlh58f                          0.0                          0.0
# waasc88ia3                          0.0                          0.0
# ...                                 ...                          ...
# k1m023wfmg                          0.0                          0.0
# g1ekfb3bu8                          0.0                          0.0
# vy3vwm9oja                          0.0                          0.0
# 7iwh7vh19t                          0.0                          2.0
# yh74l49bl1                          0.0                          0.0
# ydzqhu05rx                          0.0                          0.0
# xkivadk1af                          0.0                          0.0
# 3cnu02brvq                          0.0                          0.0
# nbmnlo5q73                          0.0                          0.0
# wg6gcq5hlj                          0.0                          1.0
# sxu3clenta                          0.0                          0.0
# xjmld7nqck                          0.0                          0.0
# v2elwr037d                          0.0                          0.0
# 1n2429cp96                          0.0                          0.0
# 620o2hyynw                          0.0                          0.0
# hc7bboi9gr                          0.0                          0.0
# r8ajngns16                          0.0                          0.0
# fn6zvy0sm4                          0.0                          0.0
# dq48lzniy1                          0.0                          0.0
# lo1wc1t110                          0.0                          0.0
# s2dhyi4hst                          0.0                          2.0
# jjbqps9hvb                          0.0                          0.0
# 7quv1cccrv                          0.0                          0.0
# ck8c7dyd1i                          0.0                          0.0
# yorn50cin7                          0.0                          0.0
# wostlok7dp                          0.0                          0.0
# fs115l1v0k                          0.0                          0.0
# mo7yckrlc5                          0.0                         24.0
# 6p5y5o0jbx                          0.0                          0.0
# acxy7vq566                          0.0                          0.0
#
#             action_detail_your_reservations  action_detail_your_trips
# yq9l4gresp                              0.0                       0.0
# rkysvxwgif                              0.0                       0.0
# 4okzo0h31v                              0.0                       0.0
# waj2fu7aqw                              0.0                       0.0
# pc3f35de0s                              0.0                       0.0
# 783nyam7lf                              0.0                       0.0
# 5lolu8ir9b                              0.0                       0.0
# nl1xby3e4e                              0.0                       0.0
# e21s43n1yn                              0.0                       0.0
# csexvvmfgk                              0.0                       0.0
# h3o5l1qzmg                              0.0                       0.0
# qbtqlldd1w                              0.0                       0.0
# i903ill900                              0.0                       0.0
# 0y381k04if                              0.0                       0.0
# 9ix98y3bun                              0.0                       0.0
# qvl0x4w142                              0.0                       0.0
# de921vj0ba                              0.0                       0.0
# sj8so99onw                              0.0                       0.0
# wq3m98fl7d                              0.0                       0.0
# jym9msc1du                              0.0                       0.0
# 9liag7c30i                              0.0                       0.0
# 7l4otb8cr2                              0.0                       0.0
# nvx9geb66e                              0.0                       2.0
# my51va0pls                              0.0                       0.0
# e9wnmbr4ti                              0.0                       0.0
# pqq2szeh2g                              0.0                       0.0
# pqadfv49vt                              0.0                       0.0
# ybgil155f4                              0.0                       0.0
# o58yzlh58f                              0.0                       1.0
# waasc88ia3                              0.0                       2.0
# ...                                     ...                       ...
# k1m023wfmg                              0.0                       0.0
# g1ekfb3bu8                              0.0                       4.0
# vy3vwm9oja                              0.0                       0.0
# 7iwh7vh19t                              0.0                       0.0
# yh74l49bl1                              0.0                       0.0
# ydzqhu05rx                              0.0                       0.0
# xkivadk1af                              0.0                       0.0
# 3cnu02brvq                              0.0                       0.0
# nbmnlo5q73                              0.0                       0.0
# wg6gcq5hlj                              0.0                       1.0
# sxu3clenta                              0.0                       0.0
# xjmld7nqck                              0.0                       0.0
# v2elwr037d                              0.0                       0.0
# 1n2429cp96                              0.0                       0.0
# 620o2hyynw                              0.0                       2.0
# hc7bboi9gr                              0.0                       0.0
# r8ajngns16                              0.0                       0.0
# fn6zvy0sm4                              0.0                       0.0
# dq48lzniy1                              0.0                       0.0
# lo1wc1t110                              0.0                       0.0
# s2dhyi4hst                              0.0                       0.0
# jjbqps9hvb                              0.0                       0.0
# 7quv1cccrv                              0.0                       0.0
# ck8c7dyd1i                              0.0                       0.0
# yorn50cin7                              0.0                       2.0
# wostlok7dp                              0.0                       0.0
# fs115l1v0k                              0.0                       0.0
# mo7yckrlc5                              0.0                       4.0
# 6p5y5o0jbx                              0.0                       0.0
# acxy7vq566                              0.0                       0.0
#
# [51670 rows x 349 columns]

# %%
features_test
# Out:
#              age  gende_unknown  gende_male  gende_female  gende_other  \
# psgai7h0uw  26.0              0           1             0            0
# gqqvzs7r6d  -1.0              1           0             0            0
# tbzqazua9i  41.0              1           0             0            0
# z1pkxltnv3  20.0              1           0             0            0
# 03gc0lvuq8  -1.0              1           0             0            0
# ogybclbom1  30.0              0           0             1            0
# ix1yn3labd  33.0              1           0             0            0
# 0kdi649bsj  26.0              0           0             1            0
# xa1idbftcf  -1.0              1           0             0            0
# igvz8ifn3w  -1.0              1           0             0            0
# 0k5512tvai  44.0              0           1             0            0
# h6gmjr53vh  -1.0              1           0             0            0
# m4lppm20oh  -1.0              1           0             0            0
# bwvogy9dps  -1.0              1           0             0            0
# jjk06w5k3p  -1.0              0           0             1            0
# glujz6stmh  42.0              0           1             0            0
# i74jkf0yqy  26.0              1           0             0            0
# mqkeo6svv3  36.0              0           0             1            0
# o8ybu4av4z  26.0              0           1             0            0
# iwnvbneqb5  -1.0              0           0             1            0
# 60xydq3td1  27.0              0           0             1            0
# cuezhfqj4b  38.0              0           1             0            0
# y1encsf4kr  29.0              0           1             0            0
# 857cigp5v7  25.0              0           1             0            0
# dnfuxxs9u1  32.0              0           1             0            0
# w7aamh64me  55.0              1           0             0            0
# ikmqyzd4ju  -1.0              1           0             0            0
# p19g9vf5yr  -1.0              1           0             0            0
# 6vmf0c5cva  24.0              0           1             0            0
# thtlwapusx  31.0              0           0             1            0
# ...          ...            ...         ...           ...          ...
# b08nob1dq1  30.0              1           0             0            0
# 0ertylift3  32.0              0           0             1            0
# jgit5ntief  32.0              0           0             1            0
# 32zruw98m7  -1.0              1           0             0            0
# et8pwvb8kv  25.0              0           0             1            0
# hwvl2hh3ta  -1.0              1           0             0            0
# 1l6qznqzl6  63.0              0           0             1            0
# o6eav7q6f7  29.0              0           1             0            0
# 1x2mxrg2go  30.0              0           1             0            0
# 8kcs9qwnqm  31.0              0           1             0            0
# mrdvkyyv25  33.0              0           1             0            0
# 1exlsnxxdo  -1.0              1           0             0            0
# ribhgukbcu  29.0              0           0             1            0
# 19hc8pv4f6  35.0              1           0             0            0
# b35jqhywzf  70.0              1           0             0            0
# gz5pbuxjob  33.0              0           0             1            0
# n539ym8nwy  36.0              1           0             0            0
# r2c91m7kxy  28.0              0           1             0            0
# 2jsejtsk6v  -1.0              1           0             0            0
# gguhb4ovfx  -1.0              1           0             0            0
# sp3ryt8b8s  -1.0              1           0             0            0
# k8bl2neikd  34.0              1           0             0            0
# izylpc9dpx  46.0              1           0             0            0
# g6enzxo0lf  32.0              1           0             0            0
# ic4mi2ys3q  35.0              0           1             0            0
# e4boxkcmrb  -1.0              1           0             0            0
# c98ncpdz1u  -1.0              1           0             0            0
# p7evncrcs2  35.0              0           0             1            0
# 3bbmubbad1  34.0              0           0             1            0
# bg58fq4nqv  42.0              0           0             1            0
#
#             signu_facebook  signu_basic  signu_google  signu_weibo  signu_0  \
# psgai7h0uw               1            0             0            0        1
# gqqvzs7r6d               0            1             0            0        0
# tbzqazua9i               0            1             0            0        1
# z1pkxltnv3               0            1             0            0        1
# 03gc0lvuq8               0            1             0            0        1
# ogybclbom1               0            1             0            0        1
# ix1yn3labd               0            1             0            0        1
# 0kdi649bsj               0            1             0            0        1
# xa1idbftcf               0            1             0            0        0
# igvz8ifn3w               0            1             0            0        1
# 0k5512tvai               0            1             0            0        1
# h6gmjr53vh               0            1             0            0        1
# m4lppm20oh               0            1             0            0        1
# bwvogy9dps               0            1             0            0        1
# jjk06w5k3p               1            0             0            0        0
# glujz6stmh               1            0             0            0        1
# i74jkf0yqy               0            1             0            0        1
# mqkeo6svv3               1            0             0            0        1
# o8ybu4av4z               1            0             0            0        0
# iwnvbneqb5               0            1             0            0        1
# 60xydq3td1               1            0             0            0        1
# cuezhfqj4b               1            0             0            0        1
# y1encsf4kr               1            0             0            0        0
# 857cigp5v7               0            1             0            0        1
# dnfuxxs9u1               0            1             0            0        1
# w7aamh64me               0            1             0            0        1
# ikmqyzd4ju               0            1             0            0        1
# p19g9vf5yr               0            1             0            0        0
# 6vmf0c5cva               0            1             0            0        1
# thtlwapusx               1            0             0            0        1
# ...                    ...          ...           ...          ...      ...
# b08nob1dq1               0            1             0            0        1
# 0ertylift3               0            0             1            0        0
# jgit5ntief               1            0             0            0        0
# 32zruw98m7               0            1             0            0        1
# et8pwvb8kv               1            0             0            0        1
# hwvl2hh3ta               0            1             0            0        1
# 1l6qznqzl6               0            1             0            0        1
# o6eav7q6f7               0            1             0            0        1
# 1x2mxrg2go               0            1             0            0        1
# 8kcs9qwnqm               0            1             0            0        1
# mrdvkyyv25               1            0             0            0        1
# 1exlsnxxdo               0            1             0            0        0
# ribhgukbcu               1            0             0            0        1
# 19hc8pv4f6               0            1             0            0        1
# b35jqhywzf               0            1             0            0        1
# gz5pbuxjob               0            1             0            0        1
# n539ym8nwy               0            1             0            0        1
# r2c91m7kxy               0            1             0            0        1
# 2jsejtsk6v               0            1             0            0        0
# gguhb4ovfx               0            1             0            0        1
# sp3ryt8b8s               0            1             0            0        0
# k8bl2neikd               0            1             0            0        1
# izylpc9dpx               0            1             0            0        1
# g6enzxo0lf               0            1             0            0        1
# ic4mi2ys3q               1            0             0            0        1
# e4boxkcmrb               0            1             0            0        1
# c98ncpdz1u               0            1             0            0        1
# p7evncrcs2               0            1             0            0        1
# 3bbmubbad1               0            1             0            0        1
# bg58fq4nqv               1            0             0            0        0
#
#                       ...             action_detail_view_resolutions  \
# psgai7h0uw            ...                                        0.0
# gqqvzs7r6d            ...                                        0.0
# tbzqazua9i            ...                                        0.0
# z1pkxltnv3            ...                                        0.0
# 03gc0lvuq8            ...                                        0.0
# ogybclbom1            ...                                        0.0
# ix1yn3labd            ...                                        0.0
# 0kdi649bsj            ...                                        0.0
# xa1idbftcf            ...                                        0.0
# igvz8ifn3w            ...                                        0.0
# 0k5512tvai            ...                                        0.0
# h6gmjr53vh            ...                                        0.0
# m4lppm20oh            ...                                        0.0
# bwvogy9dps            ...                                        0.0
# jjk06w5k3p            ...                                        0.0
# glujz6stmh            ...                                        0.0
# i74jkf0yqy            ...                                        0.0
# mqkeo6svv3            ...                                        0.0
# o8ybu4av4z            ...                                        0.0
# iwnvbneqb5            ...                                        0.0
# 60xydq3td1            ...                                        0.0
# cuezhfqj4b            ...                                        0.0
# y1encsf4kr            ...                                        0.0
# 857cigp5v7            ...                                        0.0
# dnfuxxs9u1            ...                                        0.0
# w7aamh64me            ...                                        0.0
# ikmqyzd4ju            ...                                        0.0
# p19g9vf5yr            ...                                        0.0
# 6vmf0c5cva            ...                                        0.0
# thtlwapusx            ...                                        0.0
# ...                   ...                                        ...
# b08nob1dq1            ...                                        0.0
# 0ertylift3            ...                                        0.0
# jgit5ntief            ...                                        0.0
# 32zruw98m7            ...                                        0.0
# et8pwvb8kv            ...                                        0.0
# hwvl2hh3ta            ...                                        0.0
# 1l6qznqzl6            ...                                        0.0
# o6eav7q6f7            ...                                        0.0
# 1x2mxrg2go            ...                                        0.0
# 8kcs9qwnqm            ...                                        0.0
# mrdvkyyv25            ...                                        0.0
# 1exlsnxxdo            ...                                        0.0
# ribhgukbcu            ...                                        0.0
# 19hc8pv4f6            ...                                        0.0
# b35jqhywzf            ...                                        0.0
# gz5pbuxjob            ...                                        0.0
# n539ym8nwy            ...                                        0.0
# r2c91m7kxy            ...                                        0.0
# 2jsejtsk6v            ...                                        0.0
# gguhb4ovfx            ...                                        0.0
# sp3ryt8b8s            ...                                        0.0
# k8bl2neikd            ...                                        0.0
# izylpc9dpx            ...                                        0.0
# g6enzxo0lf            ...                                        0.0
# ic4mi2ys3q            ...                                        0.0
# e4boxkcmrb            ...                                        0.0
# c98ncpdz1u            ...                                        0.0
# p7evncrcs2            ...                                        0.0
# 3bbmubbad1            ...                                        0.0
# bg58fq4nqv            ...                                        0.0
#
#             action_detail_view_search_results  \
# psgai7h0uw                                0.0
# gqqvzs7r6d                                1.0
# tbzqazua9i                                0.0
# z1pkxltnv3                               23.0
# 03gc0lvuq8                               12.0
# ogybclbom1                                0.0
# ix1yn3labd                                0.0
# 0kdi649bsj                                0.0
# xa1idbftcf                                7.0
# igvz8ifn3w                                9.0
# 0k5512tvai                               28.0
# h6gmjr53vh                                1.0
# m4lppm20oh                                3.0
# bwvogy9dps                                3.0
# jjk06w5k3p                                0.0
# glujz6stmh                                0.0
# i74jkf0yqy                                0.0
# mqkeo6svv3                               32.0
# o8ybu4av4z                                0.0
# iwnvbneqb5                               51.0
# 60xydq3td1                                3.0
# cuezhfqj4b                                6.0
# y1encsf4kr                                0.0
# 857cigp5v7                                0.0
# dnfuxxs9u1                                0.0
# w7aamh64me                               47.0
# ikmqyzd4ju                                0.0
# p19g9vf5yr                                6.0
# 6vmf0c5cva                                4.0
# thtlwapusx                                0.0
# ...                                       ...
# b08nob1dq1                                0.0
# 0ertylift3                                6.0
# jgit5ntief                                0.0
# 32zruw98m7                               49.0
# et8pwvb8kv                               33.0
# hwvl2hh3ta                               55.0
# 1l6qznqzl6                                0.0
# o6eav7q6f7                               44.0
# 1x2mxrg2go                               10.0
# 8kcs9qwnqm                               39.0
# mrdvkyyv25                                0.0
# 1exlsnxxdo                                0.0
# ribhgukbcu                               14.0
# 19hc8pv4f6                               69.0
# b35jqhywzf                                1.0
# gz5pbuxjob                               29.0
# n539ym8nwy                                0.0
# r2c91m7kxy                               15.0
# 2jsejtsk6v                               14.0
# gguhb4ovfx                                0.0
# sp3ryt8b8s                               16.0
# k8bl2neikd                               20.0
# izylpc9dpx                                0.0
# g6enzxo0lf                               12.0
# ic4mi2ys3q                               11.0
# e4boxkcmrb                                0.0
# c98ncpdz1u                                4.0
# p7evncrcs2                               26.0
# 3bbmubbad1                                0.0
# bg58fq4nqv                                3.0
#
#             action_detail_view_security_checks  \
# psgai7h0uw                                 0.0
# gqqvzs7r6d                                 0.0
# tbzqazua9i                                 0.0
# z1pkxltnv3                                 0.0
# 03gc0lvuq8                                 0.0
# ogybclbom1                                 0.0
# ix1yn3labd                                 0.0
# 0kdi649bsj                                 0.0
# xa1idbftcf                                 0.0
# igvz8ifn3w                                 0.0
# 0k5512tvai                                 0.0
# h6gmjr53vh                                 0.0
# m4lppm20oh                                 0.0
# bwvogy9dps                                 0.0
# jjk06w5k3p                                 0.0
# glujz6stmh                                 0.0
# i74jkf0yqy                                 0.0
# mqkeo6svv3                                 0.0
# o8ybu4av4z                                 0.0
# iwnvbneqb5                                 0.0
# 60xydq3td1                                 0.0
# cuezhfqj4b                                 0.0
# y1encsf4kr                                 0.0
# 857cigp5v7                                 0.0
# dnfuxxs9u1                                 0.0
# w7aamh64me                                 0.0
# ikmqyzd4ju                                 0.0
# p19g9vf5yr                                 0.0
# 6vmf0c5cva                                 0.0
# thtlwapusx                                 0.0
# ...                                        ...
# b08nob1dq1                                 0.0
# 0ertylift3                                 0.0
# jgit5ntief                                 0.0
# 32zruw98m7                                 0.0
# et8pwvb8kv                                 0.0
# hwvl2hh3ta                                 0.0
# 1l6qznqzl6                                 0.0
# o6eav7q6f7                                 0.0
# 1x2mxrg2go                                 0.0
# 8kcs9qwnqm                                 0.0
# mrdvkyyv25                                 0.0
# 1exlsnxxdo                                 0.0
# ribhgukbcu                                 0.0
# 19hc8pv4f6                                 0.0
# b35jqhywzf                                 0.0
# gz5pbuxjob                                 0.0
# n539ym8nwy                                 0.0
# r2c91m7kxy                                 0.0
# 2jsejtsk6v                                 0.0
# gguhb4ovfx                                 0.0
# sp3ryt8b8s                                 0.0
# k8bl2neikd                                 0.0
# izylpc9dpx                                 0.0
# g6enzxo0lf                                 0.0
# ic4mi2ys3q                                 0.0
# e4boxkcmrb                                 0.0
# c98ncpdz1u                                 0.0
# p7evncrcs2                                 0.0
# 3bbmubbad1                                 0.0
# bg58fq4nqv                                 0.0
#
#             action_detail_view_user_real_names  action_detail_wishlist  \
# psgai7h0uw                                 0.0                     0.0
# gqqvzs7r6d                                 0.0                     0.0
# tbzqazua9i                                 0.0                     0.0
# z1pkxltnv3                                 0.0                     0.0
# 03gc0lvuq8                                 0.0                     0.0
# ogybclbom1                                 0.0                     0.0
# ix1yn3labd                                 0.0                     0.0
# 0kdi649bsj                                 0.0                     0.0
# xa1idbftcf                                 0.0                     0.0
# igvz8ifn3w                                 0.0                     0.0
# 0k5512tvai                                 0.0                     0.0
# h6gmjr53vh                                 0.0                     0.0
# m4lppm20oh                                 0.0                     0.0
# bwvogy9dps                                 0.0                     0.0
# jjk06w5k3p                                 0.0                     0.0
# glujz6stmh                                 0.0                     0.0
# i74jkf0yqy                                 0.0                     0.0
# mqkeo6svv3                                 0.0                     0.0
# o8ybu4av4z                                 0.0                     0.0
# iwnvbneqb5                                 0.0                     1.0
# 60xydq3td1                                 0.0                     0.0
# cuezhfqj4b                                 0.0                     0.0
# y1encsf4kr                                 0.0                     0.0
# 857cigp5v7                                 0.0                     0.0
# dnfuxxs9u1                                 0.0                     0.0
# w7aamh64me                                 0.0                     0.0
# ikmqyzd4ju                                 0.0                     0.0
# p19g9vf5yr                                 0.0                     0.0
# 6vmf0c5cva                                 0.0                     0.0
# thtlwapusx                                 0.0                     0.0
# ...                                        ...                     ...
# b08nob1dq1                                 0.0                     0.0
# 0ertylift3                                 0.0                     0.0
# jgit5ntief                                 0.0                     0.0
# 32zruw98m7                                 0.0                     0.0
# et8pwvb8kv                                 0.0                     0.0
# hwvl2hh3ta                                 0.0                     0.0
# 1l6qznqzl6                                 0.0                     0.0
# o6eav7q6f7                                 0.0                     0.0
# 1x2mxrg2go                                 0.0                     0.0
# 8kcs9qwnqm                                 0.0                     0.0
# mrdvkyyv25                                 0.0                     0.0
# 1exlsnxxdo                                 0.0                     0.0
# ribhgukbcu                                 0.0                     0.0
# 19hc8pv4f6                                 0.0                     0.0
# b35jqhywzf                                 0.0                     0.0
# gz5pbuxjob                                 0.0                     0.0
# n539ym8nwy                                 0.0                     0.0
# r2c91m7kxy                                 0.0                     0.0
# 2jsejtsk6v                                 0.0                     0.0
# gguhb4ovfx                                 0.0                     0.0
# sp3ryt8b8s                                 0.0                     0.0
# k8bl2neikd                                 0.0                     0.0
# izylpc9dpx                                 0.0                     0.0
# g6enzxo0lf                                 0.0                     0.0
# ic4mi2ys3q                                 0.0                     0.0
# e4boxkcmrb                                 0.0                     0.0
# c98ncpdz1u                                 0.0                     0.0
# p7evncrcs2                                 0.0                     0.0
# 3bbmubbad1                                 0.0                     0.0
# bg58fq4nqv                                 0.0                     0.0
#
#             action_detail_wishlist_content_update  \
# psgai7h0uw                                    0.0
# gqqvzs7r6d                                    0.0
# tbzqazua9i                                    0.0
# z1pkxltnv3                                    7.0
# 03gc0lvuq8                                    7.0
# ogybclbom1                                    0.0
# ix1yn3labd                                    0.0
# 0kdi649bsj                                    0.0
# xa1idbftcf                                    0.0
# igvz8ifn3w                                    6.0
# 0k5512tvai                                    5.0
# h6gmjr53vh                                    6.0
# m4lppm20oh                                    5.0
# bwvogy9dps                                    1.0
# jjk06w5k3p                                    0.0
# glujz6stmh                                    6.0
# i74jkf0yqy                                    3.0
# mqkeo6svv3                                   24.0
# o8ybu4av4z                                    0.0
# iwnvbneqb5                                   50.0
# 60xydq3td1                                    3.0
# cuezhfqj4b                                   22.0
# y1encsf4kr                                    0.0
# 857cigp5v7                                    1.0
# dnfuxxs9u1                                    0.0
# w7aamh64me                                   58.0
# ikmqyzd4ju                                    0.0
# p19g9vf5yr                                    0.0
# 6vmf0c5cva                                    7.0
# thtlwapusx                                    0.0
# ...                                           ...
# b08nob1dq1                                    1.0
# 0ertylift3                                    0.0
# jgit5ntief                                    0.0
# 32zruw98m7                                    8.0
# et8pwvb8kv                                   20.0
# hwvl2hh3ta                                   45.0
# 1l6qznqzl6                                    6.0
# o6eav7q6f7                                   15.0
# 1x2mxrg2go                                   11.0
# 8kcs9qwnqm                                    3.0
# mrdvkyyv25                                    0.0
# 1exlsnxxdo                                    0.0
# ribhgukbcu                                    3.0
# 19hc8pv4f6                                    9.0
# b35jqhywzf                                    2.0
# gz5pbuxjob                                   21.0
# n539ym8nwy                                    0.0
# r2c91m7kxy                                   13.0
# 2jsejtsk6v                                    0.0
# gguhb4ovfx                                    3.0
# sp3ryt8b8s                                    6.0
# k8bl2neikd                                    7.0
# izylpc9dpx                                    0.0
# g6enzxo0lf                                    2.0
# ic4mi2ys3q                                    3.0
# e4boxkcmrb                                    0.0
# c98ncpdz1u                                    1.0
# p7evncrcs2                                   25.0
# 3bbmubbad1                                    2.0
# bg58fq4nqv                                    0.0
#
#             action_detail_wishlist_note  action_detail_your_listings  \
# psgai7h0uw                          0.0                          0.0
# gqqvzs7r6d                          0.0                          0.0
# tbzqazua9i                          0.0                          0.0
# z1pkxltnv3                          0.0                          0.0
# 03gc0lvuq8                          0.0                          0.0
# ogybclbom1                          0.0                          0.0
# ix1yn3labd                          0.0                          0.0
# 0kdi649bsj                          0.0                          0.0
# xa1idbftcf                          0.0                          0.0
# igvz8ifn3w                          0.0                          0.0
# 0k5512tvai                          0.0                          0.0
# h6gmjr53vh                          0.0                          0.0
# m4lppm20oh                          0.0                          0.0
# bwvogy9dps                          0.0                          0.0
# jjk06w5k3p                          0.0                          0.0
# glujz6stmh                          0.0                          0.0
# i74jkf0yqy                          0.0                          0.0
# mqkeo6svv3                          0.0                          0.0
# o8ybu4av4z                          0.0                          0.0
# iwnvbneqb5                          0.0                          0.0
# 60xydq3td1                          0.0                          0.0
# cuezhfqj4b                          0.0                          0.0
# y1encsf4kr                          0.0                          0.0
# 857cigp5v7                          0.0                          0.0
# dnfuxxs9u1                          0.0                          0.0
# w7aamh64me                          0.0                          0.0
# ikmqyzd4ju                          0.0                          0.0
# p19g9vf5yr                          0.0                          0.0
# 6vmf0c5cva                          0.0                          0.0
# thtlwapusx                          0.0                          0.0
# ...                                 ...                          ...
# b08nob1dq1                          0.0                          0.0
# 0ertylift3                          0.0                          0.0
# jgit5ntief                          0.0                          0.0
# 32zruw98m7                          0.0                          0.0
# et8pwvb8kv                          0.0                          0.0
# hwvl2hh3ta                          0.0                          0.0
# 1l6qznqzl6                          0.0                          0.0
# o6eav7q6f7                          0.0                          0.0
# 1x2mxrg2go                          0.0                          0.0
# 8kcs9qwnqm                          0.0                          2.0
# mrdvkyyv25                          0.0                          0.0
# 1exlsnxxdo                          0.0                          0.0
# ribhgukbcu                          0.0                          0.0
# 19hc8pv4f6                          0.0                          0.0
# b35jqhywzf                          0.0                          0.0
# gz5pbuxjob                          0.0                          0.0
# n539ym8nwy                          0.0                          0.0
# r2c91m7kxy                          0.0                          0.0
# 2jsejtsk6v                          0.0                          1.0
# gguhb4ovfx                          0.0                          0.0
# sp3ryt8b8s                          0.0                          0.0
# k8bl2neikd                          0.0                          0.0
# izylpc9dpx                          0.0                          0.0
# g6enzxo0lf                          0.0                          0.0
# ic4mi2ys3q                          0.0                          2.0
# e4boxkcmrb                          0.0                          0.0
# c98ncpdz1u                          0.0                          0.0
# p7evncrcs2                          0.0                          0.0
# 3bbmubbad1                          0.0                          0.0
# bg58fq4nqv                          0.0                          0.0
#
#             action_detail_your_reservations  action_detail_your_trips
# psgai7h0uw                              0.0                       0.0
# gqqvzs7r6d                              0.0                       0.0
# tbzqazua9i                              0.0                       0.0
# z1pkxltnv3                              0.0                       0.0
# 03gc0lvuq8                              0.0                       0.0
# ogybclbom1                              0.0                       0.0
# ix1yn3labd                              0.0                       0.0
# 0kdi649bsj                              0.0                       0.0
# xa1idbftcf                              0.0                       0.0
# igvz8ifn3w                              0.0                       0.0
# 0k5512tvai                              0.0                       0.0
# h6gmjr53vh                              0.0                       0.0
# m4lppm20oh                              0.0                       0.0
# bwvogy9dps                              0.0                       2.0
# jjk06w5k3p                              0.0                       0.0
# glujz6stmh                              0.0                       0.0
# i74jkf0yqy                              0.0                       0.0
# mqkeo6svv3                              0.0                       0.0
# o8ybu4av4z                              0.0                       0.0
# iwnvbneqb5                              0.0                       1.0
# 60xydq3td1                              0.0                       0.0
# cuezhfqj4b                              0.0                       0.0
# y1encsf4kr                              0.0                       0.0
# 857cigp5v7                              0.0                       0.0
# dnfuxxs9u1                              0.0                       0.0
# w7aamh64me                              0.0                       2.0
# ikmqyzd4ju                              0.0                       0.0
# p19g9vf5yr                              0.0                       0.0
# 6vmf0c5cva                              0.0                       2.0
# thtlwapusx                              0.0                       0.0
# ...                                     ...                       ...
# b08nob1dq1                              0.0                       0.0
# 0ertylift3                              0.0                       0.0
# jgit5ntief                              0.0                       0.0
# 32zruw98m7                              0.0                       0.0
# et8pwvb8kv                              0.0                       0.0
# hwvl2hh3ta                              0.0                       0.0
# 1l6qznqzl6                              0.0                       1.0
# o6eav7q6f7                              0.0                       0.0
# 1x2mxrg2go                              0.0                       0.0
# 8kcs9qwnqm                              0.0                       0.0
# mrdvkyyv25                              0.0                       0.0
# 1exlsnxxdo                              0.0                       0.0
# ribhgukbcu                              0.0                       0.0
# 19hc8pv4f6                              0.0                       0.0
# b35jqhywzf                              0.0                       0.0
# gz5pbuxjob                              0.0                       0.0
# n539ym8nwy                              0.0                       0.0
# r2c91m7kxy                              0.0                       2.0
# 2jsejtsk6v                              0.0                       0.0
# gguhb4ovfx                              0.0                       0.0
# sp3ryt8b8s                              0.0                       0.0
# k8bl2neikd                              0.0                       0.0
# izylpc9dpx                              0.0                       0.0
# g6enzxo0lf                              0.0                       0.0
# ic4mi2ys3q                              0.0                       2.0
# e4boxkcmrb                              0.0                       1.0
# c98ncpdz1u                              0.0                       0.0
# p7evncrcs2                              0.0                       0.0
# 3bbmubbad1                              0.0                       4.0
# bg58fq4nqv                              0.0                       0.0
#
# [22145 rows x 349 columns]

# %%
labels_train
# Out:
# array([7, 7, 7, ..., 7, 4, 7])

# %%
labels_test
# Out:
# array([ 7,  7,  7, ..., 10, 10,  7])

# %%
#Decision Tree
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf.fit(features_train, labels_train)
prediction = clf.predict(features_test)
#Computing Accuracy
from sklearn.metrics import accuracy_score
print (accuracy_score(prediction, labels_test))
# Out:
# 0.57426055543

# %%
#Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(features_train, labels_train)
prediction = clf.predict(features_test)
#Computing Accuracy
print (accuracy_score(prediction, labels_test))
# Out:
# 0.602077218334

# %%
from sklearn import svm
#Try

# %% [markdown]
# ## Approach 3

# %% [markdown]
# GridSearchCV

# %%
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn import decomposition, grid_search

#Grid Search - Used to find the best combination of parameters
XGB_model = xgb.XGBClassifier(objective = 'multi:softprob', subsample=0.5, colsample_bytree=0.5, seed = 0)
#softprob : gives probabily whether it belongs to a class
param_grid = {'max_depth':[5], 'learning_rate':[0.1], 'n_estimators':[5]}
model = grid_search.GridSearchCV(estimator = XGB_model, param_grid = param_grid, scoring = 'accuracy', verbose = 10, n_jobs = 1, iid = True, refit = True, cv=3)

#model.fit(x, y)
model.fit(features_train, labels_train)
print ("Best score: %0.3f" % model.best_score_)
print ("Best parameters set:")
best_parameters = model.best_estimator_.get_params()
for param_name in sorted(param_grid.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] learning_rate=0.1, max_depth=5, n_estimators=5 ..................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=5, score=0.690272 -   6.3s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=5 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.3s remaining:    0.0s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=5, score=0.679981 -   6.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=5 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   12.3s remaining:    0.0s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=5, score=0.686433 -   6.5s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   18.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   18.7s finished
# Best score: 0.686
# Best parameters set:
# 	learning_rate: 0.1
# 	max_depth: 5
# 	n_estimators: 5

# %%
from sklearn.metrics import log_loss

#Gradient boosting
#xgb = XGBClassifier(max_depth = 5, learning_rate = 0.1, n_estimators = 5, objective = 'multi:softprob', seed = 0)
#xgb.fit(features_train, labels_train, verbose = False)
#y_gb = xgb.predict_proba(features_test)
y_gb = model.predict_proba(features_test)
print ('{:20s} {:2s} {:1.7f}'.format('XGB_Reg:', 'logloss =>', log_loss(labels_test, y_gb)))
# Out:
# XGB_Reg:             logloss => 1.6335446
